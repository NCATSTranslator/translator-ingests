# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#FILTER-Missing-values" data-toc-modified-id="FILTER-Missing-values-1">FILTER Missing values</a></span></li><li><span><a href="#interaction_types" data-toc-modified-id="interaction_types-2">interaction_types</a></span><ul class="toc-item"><li><span><a href="#EDA-&quot;|-delimited&quot;-values" data-toc-modified-id="EDA-&quot;|-delimited&quot;-values-2.1">EDA "|-delimited" values</a></span></li><li><span><a href="#Split-&quot;|-delimited&quot;" data-toc-modified-id="Split-&quot;|-delimited&quot;-2.2">Split "|-delimited"</a></span></li></ul></li><li><span><a href="#EDA-interaction_source_db_name" data-toc-modified-id="EDA-interaction_source_db_name-3">EDA interaction_source_db_name</a></span></li><li><span><a href="#FILTER-Namespaces" data-toc-modified-id="FILTER-Namespaces-4">FILTER Namespaces</a></span></li><li><span><a href="#EDA-drug_is_immunotherapy" data-toc-modified-id="EDA-drug_is_immunotherapy-5">EDA drug_is_immunotherapy</a></span></li><li><span><a href="#EDA-Merging-by-gene-drug-pairs" data-toc-modified-id="EDA-Merging-by-gene-drug-pairs-6">EDA Merging by gene-drug pairs</a></span><ul class="toc-item"><li><span><a href="#interaction_types" data-toc-modified-id="interaction_types-6.1">interaction_types</a></span></li><li><span><a href="#interaction_source_db_name" data-toc-modified-id="interaction_source_db_name-6.2">interaction_source_db_name</a></span></li></ul></li><li><span><a href="#EDA-Merging-by-gene-drug-interaction_type-sets" data-toc-modified-id="EDA-Merging-by-gene-drug-interaction_type-sets-7">EDA Merging by gene-drug-interaction_type sets</a></span></li><li><span><a href="#Experimental" data-toc-modified-id="Experimental-8">Experimental</a></span><ul class="toc-item"><li><span><a href="#sources-logic" data-toc-modified-id="sources-logic-8.1">sources logic</a></span></li><li><span><a href="#scores-logic" data-toc-modified-id="scores-logic-8.2">scores logic</a></span></li></ul></li></ul></div>

# %% [markdown]
# # DGIdb notebook: EDA

# %%
## for notebook only 

## allows multiple lines of code to print from one code block
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

## for printing
from pprint import pprint

## for loading locally-stored files
import pathlib

# %%
import pandas as pd

## NOT for parser: for viewing df only
pd.options.display.max_columns = None
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# This notebook was originally written using the **2024-Dec** interactions.tsv from https://dgidb.org/downloads. Its "last modified" date is Fri, **06 Dec 2024** 15:20:44 GMT, according to the headers returned from a HEAD request to [its download link](https://dgidb.org/data/2024-Dec/interactions.tsv).
#
# <br>
#
# I didn't use the "latest" interactions.tsv because its "last modified" date is Mon, **10 Jun 2024** 16:04:52 GMT according to the headers returned from a HEAD request to [its download link](https://dgidb.org/data/latest/interactions.tsv)

# %% [markdown]
# The 2024-Dec file has two header lines showing the DGIdb semantic version **5.0.7** and "data" version (month-year date).
#
# ```
# # Data version: Dec-2024
# # DGIdb version: v.5.0.7
# ```

# %%
## path to raw resource file
interactions_path = pathlib.Path.home().joinpath("Desktop", 
                                                 "DGIdb_files",
                                                 "2024-Dec-interactions.tsv")

# %%
## load file in pandas directly

## should automatically treat first line after comments as header
df = pd.read_table(interactions_path, comment="#")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98920 entries, 0 to 98919
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   gene_claim_name                98915 non-null  object
#  1   gene_concept_id                90442 non-null  object
#  2   gene_name                      90442 non-null  object
#  3   drug_claim_name                98918 non-null  object
#  4   drug_concept_id                88396 non-null  object
#  5   drug_name                      88396 non-null  object
#  6   drug_is_approved               88395 non-null  object
#  7   drug_is_immunotherapy          88395 non-null  object
#  8   drug_is_antineoplastic         88395 non-null  object
#  9   interaction_source_db_name     98917 non-null  object
#  10  interaction_source_db_version  98917 non-null  object
#  11  interaction_types              35632 non-null  object
#  12  interaction_score              81740 non-null  float64
#  13  drug_specificity_score         81740 non-null  float64
#  14  gene_specificity_score         81740 non-null  float64
#  15  evidence_score                 81740 non-null  float64
# dtypes: float64(4), object(12)
# memory usage: 12.1+ MB

# %% [markdown]
# ## FILTER Missing values

# %% [markdown]
# Review:
# * **All of the columns have some missing values**
# * the entity ID columns `gene_concept_id` and `drug_concept_id` are missing thousands of values - even though DGIdb did an [entity-resolving/common-ID-assignment step](https://dgidb.org/about/overview/grouping).
# * `interaction_source_db_name` is missing a few values, which is unexpected
# * BUT it is expected that `interaction_types` is missing values, since not all sources will assign specific relationship types (ex: inhibitor).

# %%
## EDA - going through columns looking at missing values

# df[df["gene_concept_id"].isna()]

# df[df["drug_concept_id"].isna()]

## these rows look weird - unexpected drug namespace or no drug ID, lots of NAs
df[df["interaction_source_db_name"].isna()]
# Out:
#       gene_claim_name gene_concept_id gene_name     drug_claim_name  \
# 8301     NCBIGENE:362        hgnc:638      AQP5  IUPHAR.LIGAND:2129
# 12204   NCBIGENE:2721   ncbigene:2721       GLC                 NaN
# 12205   NCBIGENE:2721   ncbigene:2721       GLC                 NaN
#
#           drug_concept_id drug_name drug_is_approved drug_is_immunotherapy  \
# 8301   iuphar.ligand:2129        N&              NaN                   NaN
# 12204                 NaN       NaN              NaN                   NaN
# 12205                 NaN       NaN              NaN                   NaN
#
#       drug_is_antineoplastic interaction_source_db_name  \
# 8301                     NaN                        NaN
# 12204                    NaN                        NaN
# 12205                    NaN                        NaN
#
#       interaction_source_db_version interaction_types  interaction_score  \
# 8301                            NaN               NaN                NaN
# 12204                           NaN               NaN                NaN
# 12205                           NaN               NaN                NaN
#
#        drug_specificity_score  gene_specificity_score  evidence_score
# 8301                      NaN                     NaN             NaN
# 12204                     NaN                     NaN             NaN
# 12205                     NaN                     NaN             NaN

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **DECISION**: drop rows with NA in `gene_concept_id` OR `drug_concept_id` OR `interaction_source_db_name`.

# %%
## logs

## number of rows left after dropping NAs
## default is remove if any column has NA for the row
have_values = df.dropna(subset=["gene_concept_id", 
                                "drug_concept_id",
                                "interaction_source_db_name"]).shape[0]
print(f"{have_values} rows have both entity IDs and an underlying source" + 
      f": {have_values / df.shape[0]:.1%}\n")


## gene IDs
have_gene_id = df["gene_concept_id"].notna().sum()
print(f"{have_gene_id} rows have gene IDs: {have_gene_id / df.shape[0]:.1%}")

## drug IDs
have_drug_id = df["drug_concept_id"].notna().sum()
print(f"{have_drug_id} rows have drug IDs: {have_drug_id / df.shape[0]:.1%}")

## sources
have_source = df["interaction_source_db_name"].notna().sum()
print(f"{have_source} rows have an underlying source: {have_source / df.shape[0]:.3%}")
# Out:
# 81740 rows have both entity IDs and an underlying source: 82.6%
#
# 90442 rows have gene IDs: 91.4%
# 88396 rows have drug IDs: 89.4%
# 98917 rows have an underlying source: 99.997%

# %%
## save set of interaction_types before filtering, to compare to after

starting_interact_types = set(df["interaction_types"].unique())
len(starting_interact_types)
# Out:
# 31

# %%
## drop rows, check
## default is remove if any column has NA for the row
df = df.dropna(subset=["gene_concept_id", 
                       "drug_concept_id",
                       "interaction_source_db_name"], ignore_index=True).copy()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81740 entries, 0 to 81739
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   gene_claim_name                81735 non-null  object
#  1   gene_concept_id                81740 non-null  object
#  2   gene_name                      81740 non-null  object
#  3   drug_claim_name                81740 non-null  object
#  4   drug_concept_id                81740 non-null  object
#  5   drug_name                      81740 non-null  object
#  6   drug_is_approved               81740 non-null  object
#  7   drug_is_immunotherapy          81740 non-null  object
#  8   drug_is_antineoplastic         81740 non-null  object
#  9   interaction_source_db_name     81740 non-null  object
#  10  interaction_source_db_version  81740 non-null  object
#  11  interaction_types              30405 non-null  object
#  12  interaction_score              81740 non-null  float64
#  13  drug_specificity_score         81740 non-null  float64
#  14  gene_specificity_score         81740 non-null  float64
#  15  evidence_score                 81740 non-null  float64
# dtypes: float64(4), object(12)
# memory usage: 10.0+ MB

# %% [markdown]
# ## interaction_types

# %% [markdown]
# [2025-11-05 with 2024-Dec data]
#
# The data before filtering has the same unique interaction_types values.

# %%
## compare before-after

starting_interact_types == set(df["interaction_types"].unique())
# Out:
# True

# %%
df["interaction_types"].nunique(dropna=False)

df["interaction_types"].value_counts(dropna=False).sort_index()
# Out:
# 31
# interaction_types
# activator                      584
# activator|blocker                4
# activator|inhibitor              2
# agonist                       5882
# agonist|inhibitor               22
# agonist|modulator                2
# antibody                       298
# antibody|immunotherapy           4
# antisense oligonucleotide        4
# binder                         258
# blocker                       1807
# blocker|activator                2
# blocker|inhibitor                2
# cleavage                        83
# immunotherapy                    3
# immunotherapy|antibody           4
# inhibitor                    18692
# inhibitor|activator              2
# inhibitor|agonist               14
# inhibitor|blocker                3
# inhibitor|modulator              5
# inverse agonist                 36
# modulator                     1241
# modulator|agonist                1
# modulator|inhibitor              3
# negative modulator             133
# other/unknown                  219
# positive modulator            1013
# potentiator                     51
# vaccine                         31
# NaN                          51335
# Name: count, dtype: int64

# %%
## replace NA with "~NULL"
## makes next steps working with this column easier, will be at end alphanumerically 

df["interaction_types"] = df["interaction_types"].fillna("~NULL")

# %%
df["interaction_types"].value_counts().sort_index()
# Out:
# interaction_types
# activator                      584
# activator|blocker                4
# activator|inhibitor              2
# agonist                       5882
# agonist|inhibitor               22
# agonist|modulator                2
# antibody                       298
# antibody|immunotherapy           4
# antisense oligonucleotide        4
# binder                         258
# blocker                       1807
# blocker|activator                2
# blocker|inhibitor                2
# cleavage                        83
# immunotherapy                    3
# immunotherapy|antibody           4
# inhibitor                    18692
# inhibitor|activator              2
# inhibitor|agonist               14
# inhibitor|blocker                3
# inhibitor|modulator              5
# inverse agonist                 36
# modulator                     1241
# modulator|agonist                1
# modulator|inhibitor              3
# negative modulator             133
# other/unknown                  219
# positive modulator            1013
# potentiator                     51
# vaccine                         31
# ~NULL                        51335
# Name: count, dtype: int64

# %% [markdown]
# ### EDA "|-delimited" values

# %% [markdown]
# Muliple values, "|"-delimited (special value, needs escaping).
#
# Only a small proportion of the dataset

# %%
df_piped_types = df[df["interaction_types"].str.contains("\\|")].copy()

print(f"{df_piped_types.shape[0]} rows with |-delimited interaction_types" + 
      f": {df_piped_types.shape[0] / df.shape[0]:.3%}")

df_piped_types.head()
# Out:
# 70 rows with |-delimited interaction_types: 0.086%
#      gene_claim_name gene_concept_id gene_name      drug_claim_name  \
# 649     NCBIGENE:496        hgnc:820     ATP4B  IUPHAR.LIGAND:10038
# 654     NCBIGENE:496        hgnc:820     ATP4B  IUPHAR.LIGAND:10039
# 657     NCBIGENE:496        hgnc:820     ATP4B   IUPHAR.LIGAND:1713
# 6029     NCBIGENE:21         hgnc:33     ABCA3    IUPHAR.LIGAND:459
# 6205    NCBIGENE:277        hgnc:475     AMY1B   IUPHAR.LIGAND:9494
#
#           drug_concept_id                    drug_name drug_is_approved  \
# 649   iuphar.ligand:10038  COMPOUND 5 [PMID: 29579323]            False
# 654   iuphar.ligand:10039  COMPOUND 6 [PMID: 29579323]            False
# 657             rxcui:318       ADENOSINE TRIPHOSPHATE             True
# 6029    iuphar.ligand:459                  MRE 3008F20            False
# 6205   iuphar.ligand:9494                     CYM-5541            False
#
#      drug_is_immunotherapy drug_is_antineoplastic interaction_source_db_name  \
# 649                  False                  False        GuideToPharmacology
# 654                  False                  False        GuideToPharmacology
# 657                  False                  False        GuideToPharmacology
# 6029                 False                  False        GuideToPharmacology
# 6205                 False                  False        GuideToPharmacology
#
#      interaction_source_db_version  interaction_types  interaction_score  \
# 649                         2024.3  inhibitor|blocker           1.864421
# 654                         2024.3  inhibitor|blocker           1.864421
# 657                         2024.3  inhibitor|blocker           0.109672
# 6029                        2024.3  agonist|inhibitor           0.134546
# 6205                        2024.3  modulator|agonist           3.070812
#
#       drug_specificity_score  gene_specificity_score  evidence_score
# 649                 3.627763                0.513931             1.0
# 654                 3.627763                0.513931             1.0
# 657                 0.213398                0.513931             1.0
# 6029                0.906941                0.148351             1.0
# 6205                3.627763                0.846475             1.0

# %%
df_piped_types["interaction_types"].nunique()

df_piped_types["interaction_types"].value_counts().sort_index()
# Out:
# 14
# interaction_types
# activator|blocker          4
# activator|inhibitor        2
# agonist|inhibitor         22
# agonist|modulator          2
# antibody|immunotherapy     4
# blocker|activator          2
# blocker|inhibitor          2
# immunotherapy|antibody     4
# inhibitor|activator        2
# inhibitor|agonist         14
# inhibitor|blocker          3
# inhibitor|modulator        5
# modulator|agonist          1
# modulator|inhibitor        3
# Name: count, dtype: int64

# %% [markdown]
# **REVIEW**
#
# **Opposing:**
# * activator|blocker
# * blocker|activator
# * activator|inhibitor
# * inhibitor|activator
# * agonist|inhibitor
# * inhibitor|agonist
#
# **Close:**
# * blocker|inhibitor
# * inhibitor|blocker
#
# **One is kinda a subclass of the other?**
# * agonist|modulator
# * modulator|agonist
# * inhibitor|modulator
# * modulator|inhibitor
#
# **Identical?**
# * antibody|immunotherapy
# * immunotherapy|antibody

# %%
## are the "flipped order" types the same data? esp when same row count?
## NO - based on the few pairs I reviewed

df_piped_types[df_piped_types["interaction_types"] == "activator|inhibitor"]
df_piped_types[df_piped_types["interaction_types"] == "inhibitor|activator"]

# df_multi_types[df_multi_types["interaction_types"] == "agonist|modulator"]
# df_multi_types[df_multi_types["interaction_types"] == "modulator|agonist"]
# Out:
#       gene_claim_name gene_concept_id gene_name    drug_claim_name  \
# 9727     NCBIGENE:749      hgnc:10485      RYR3  IUPHAR.LIGAND:707
# 79392    NCBIGENE:748      hgnc:10484      RYR2  IUPHAR.LIGAND:707
#
#          drug_concept_id drug_name drug_is_approved drug_is_immunotherapy  \
# 9727   iuphar.ligand:707      CA2+            False                 False
# 79392  iuphar.ligand:707      CA2+            False                 False
#
#       drug_is_antineoplastic interaction_source_db_name  \
# 9727                   False        GuideToPharmacology
# 79392                  False        GuideToPharmacology
#
#       interaction_source_db_version    interaction_types  interaction_score  \
# 9727                         2024.3  activator|inhibitor           0.163137
# 79392                        2024.3  activator|inhibitor           0.118645
#
#        drug_specificity_score  gene_specificity_score  evidence_score
# 9727                 0.090694                1.798760             1.0
# 79392                0.090694                1.308189             1.0
#       gene_claim_name gene_concept_id gene_name    drug_claim_name  \
# 24189    NCBIGENE:747       hgnc:1165     DAGLA  IUPHAR.LIGAND:707
# 70567            BRAF       hgnc:1097      BRAF        VEMURAFENIB
#
#          drug_concept_id    drug_name drug_is_approved drug_is_immunotherapy  \
# 24189  iuphar.ligand:707         CA2+            False                 False
# 70567      rxcui:1147220  VEMURAFENIB             True                 False
#
#       drug_is_antineoplastic   interaction_source_db_name  \
# 24189                  False          GuideToPharmacology
# 70567                   True  MyCancerGenomeClinicalTrial
#
#       interaction_source_db_version    interaction_types  interaction_score  \
# 24189                        2024.3  inhibitor|activator           0.130509
# 70567              30-Feburary-2014  inhibitor|activator           1.587278
#
#        drug_specificity_score  gene_specificity_score  evidence_score
# 24189                0.090694                1.439008             1.0
# 70567                0.098048                0.071950           225.0

# %%
## from only 4 resources, mostly GuideToPharmacology

df_piped_types["interaction_source_db_name"].value_counts()
# Out:
# interaction_source_db_name
# GuideToPharmacology            60
# MyCancerGenome                  8
# MyCancerGenomeClinicalTrial     1
# ChEMBL                          1
# Name: count, dtype: int64

# %% [markdown]
# ### Split "|-delimited"

# %%
df["interaction_types"] = df["interaction_types"].str.split("|")

# %%
## this is correct - the row count in df_piped_types was the same
df[df["interaction_types"].map(len) > 1].shape[0]

df[df["interaction_types"].map(len) > 1]
# Out:
# 70
#       gene_claim_name gene_concept_id gene_name      drug_claim_name  \
# 649      NCBIGENE:496        hgnc:820     ATP4B  IUPHAR.LIGAND:10038
# 654      NCBIGENE:496        hgnc:820     ATP4B  IUPHAR.LIGAND:10039
# 657      NCBIGENE:496        hgnc:820     ATP4B   IUPHAR.LIGAND:1713
# 6029      NCBIGENE:21         hgnc:33     ABCA3    IUPHAR.LIGAND:459
# 6205     NCBIGENE:277        hgnc:475     AMY1B   IUPHAR.LIGAND:9494
# ...               ...             ...       ...                  ...
# 75509     NCBIGENE:13         hgnc:17     AADAC    IUPHAR.LIGAND:289
# 79392    NCBIGENE:748      hgnc:10484      RYR2    IUPHAR.LIGAND:707
# 79394    NCBIGENE:748      hgnc:10484      RYR2   IUPHAR.LIGAND:4303
# 80312    NCBIGENE:359        hgnc:634      AQP2   IUPHAR.LIGAND:2036
# 80438    NCBIGENE:498        hgnc:823   ATP5F1A    IUPHAR.LIGAND:708
#
#            drug_concept_id                    drug_name drug_is_approved  \
# 649    iuphar.ligand:10038  COMPOUND 5 [PMID: 29579323]            False
# 654    iuphar.ligand:10039  COMPOUND 6 [PMID: 29579323]            False
# 657              rxcui:318       ADENOSINE TRIPHOSPHATE             True
# 6029     iuphar.ligand:459                  MRE 3008F20            False
# 6205    iuphar.ligand:9494                     CYM-5541            False
# ...                    ...                          ...              ...
# 75509    iuphar.ligand:289                        AC-42            False
# 79392    iuphar.ligand:707                         CA2+            False
# 79394   iuphar.ligand:4303                    RYANODINE            False
# 80312   iuphar.ligand:2036                    BIM 23056            False
# 80438    iuphar.ligand:708                         MG2+            False
#
#       drug_is_immunotherapy drug_is_antineoplastic interaction_source_db_name  \
# 649                   False                  False        GuideToPharmacology
# 654                   False                  False        GuideToPharmacology
# 657                   False                  False        GuideToPharmacology
# 6029                  False                  False        GuideToPharmacology
# 6205                  False                  False        GuideToPharmacology
# ...                     ...                    ...                        ...
# 75509                 False                  False        GuideToPharmacology
# 79392                 False                  False        GuideToPharmacology
# 79394                 False                  False        GuideToPharmacology
# 80312                 False                  False        GuideToPharmacology
# 80438                 False                  False        GuideToPharmacology
#
#       interaction_source_db_version       interaction_types  \
# 649                          2024.3    [inhibitor, blocker]
# 654                          2024.3    [inhibitor, blocker]
# 657                          2024.3    [inhibitor, blocker]
# 6029                         2024.3    [agonist, inhibitor]
# 6205                         2024.3    [modulator, agonist]
# ...                             ...                     ...
# 75509                        2024.3    [agonist, modulator]
# 79392                        2024.3  [activator, inhibitor]
# 79394                        2024.3    [activator, blocker]
# 80312                        2024.3    [agonist, inhibitor]
# 80438                        2024.3    [activator, blocker]
#
#        interaction_score  drug_specificity_score  gene_specificity_score  \
# 649             1.864421                3.627763                0.513931
# 654             1.864421                3.627763                0.513931
# 657             0.109672                0.213398                0.513931
# 6029            0.134546                0.906941                0.148351
# 6205            3.070812                3.627763                0.846475
# ...                  ...                     ...                     ...
# 75509           0.501960                3.627763                0.138366
# 79392           0.118645                0.090694                1.308189
# 79394           1.186450                0.906941                1.308189
# 80312           0.362526                1.209254                0.299793
# 80438           0.803135                0.279059                2.878016
#
#        evidence_score
# 649               1.0
# 654               1.0
# 657               1.0
# 6029              1.0
# 6205              1.0
# ...               ...
# 75509             1.0
# 79392             1.0
# 79394             1.0
# 80312             1.0
# 80438             1.0
#
# [70 rows x 16 columns]

# %% [markdown]
# Then expand to multiple rows using pandas explode

# %%
df = df.explode("interaction_types", ignore_index=True)

## -> log
print(f"{df.shape[0]} rows after expanding rows with multiple interaction_type values")
# Out:
# 81810 rows after expanding rows with multiple interaction_type values

# %% [markdown]
# ## EDA interaction_source_db_name

# %% [markdown]
# aka "underlying sources".
# These are all single-values.
#
# Compared to the [website's "Interaction Sources"](https://dgidb.org/browse/sources), data has [all sources] - DrugBank + NCI.
# * On DrugBank, website actually doesn't have any "interaction claim" counts
# * Not clear to me what "NCI" is. National Cancer Institute?

# %%
df["interaction_source_db_name"].nunique()

df["interaction_source_db_name"].value_counts().sort_index()
# Out:
# 21
# interaction_source_db_name
# CGI                                  345
# CIViC                               1013
# CKB-CORE                            1777
# COSMIC                                34
# CancerCommons                        106
# ChEMBL                             12292
# ClearityFoundationBiomarkers         160
# ClearityFoundationClinicalTrial      240
# DTC                                23876
# DoCM                                  72
# FDA                                  402
# GuideToPharmacology                16422
# MyCancerGenome                       811
# MyCancerGenomeClinicalTrial          315
# NCI                                 6076
# OncoKB                               146
# PharmGKB                            5248
# TALC                                 564
# TEND                                2242
# TTD                                 5110
# TdgClinicalTrial                    4559
# Name: count, dtype: int64

# %%
df[df["interaction_source_db_name"] == "NCI"]
# Out:
#       gene_claim_name gene_concept_id gene_name  \
# 8               ICAM3       hgnc:5346     ICAM3
# 9               ICAM3       hgnc:5346     ICAM3
# 10              ICAM3       hgnc:5346     ICAM3
# 11              ICAM3       hgnc:5346     ICAM3
# 12              ICAM3       hgnc:5346     ICAM3
# ...               ...             ...       ...
# 81805           PTPRC       hgnc:9666     PTPRC
# 81806           PTPRC       hgnc:9666     PTPRC
# 81807           PTPRC       hgnc:9666     PTPRC
# 81808           PTPRC       hgnc:9666     PTPRC
# 81809           PTPRC       hgnc:9666     PTPRC
#
#                                         drug_claim_name     drug_concept_id  \
# 8      GRANULOCYTE MACROPHAGE COLONY-STIMULATING FACTOR          ncit:C1288
# 9                                                   PMA           ncit:C866
# 10                                               GM-CSF  iuphar.ligand:4942
# 11                                            VITAMIN D         rxcui:11253
# 12                                          INTERFERONS           ncit:C584
# ...                                                 ...                 ...
# 81805                          PROTEIN KINASE INHIBITOR          ncit:C1404
# 81806                                        OESTRADIOL         rxcui:24395
# 81807                                        PREDNISONE          rxcui:8640
# 81808                                   HEPARAN SULFATE       rxcui:2603494
# 81809                                 IMMUNOSUPPRESSIVE           ncit:C574
#
#                                                           drug_name  \
# 8      RECOMBINANT GRANULOCYTE-MACROPHAGE COLONY-STIMULATING FACTOR
# 9                                      TETRADECANOYLPHORBOL ACETATE
# 10                                                           GM-CSF
# 11                                                        VITAMIN D
# 12                                           RECOMBINANT INTERFERON
# ...                                                             ...
# 81805                                      PROTEIN KINASE INHIBITOR
# 81806                                            ESTRADIOL VALERATE
# 81807                                                    PREDNISONE
# 81808                                               HEPARAN SULFATE
# 81809                                             IMMUNOSUPPRESSANT
#
#       drug_is_approved drug_is_immunotherapy drug_is_antineoplastic  \
# 8                False                 False                   True
# 9                False                 False                   True
# 10               False                 False                  False
# 11                True                 False                  False
# 12               False                 False                   True
# ...                ...                   ...                    ...
# 81805            False                 False                  False
# 81806             True                 False                   True
# 81807             True                 False                   True
# 81808            False                 False                   True
# 81809            False                 False                  False
#
#       interaction_source_db_name interaction_source_db_version  \
# 8                            NCI             14-September-2017
# 9                            NCI             14-September-2017
# 10                           NCI             14-September-2017
# 11                           NCI             14-September-2017
# 12                           NCI             14-September-2017
# ...                          ...                           ...
# 81805                        NCI             14-September-2017
# 81806                        NCI             14-September-2017
# 81807                        NCI             14-September-2017
# 81808                        NCI             14-September-2017
# 81809                        NCI             14-September-2017
#
#       interaction_types  interaction_score  drug_specificity_score  \
# 8                 ~NULL          13.050950                3.627763
# 9                 ~NULL           0.283716                0.078864
# 10                ~NULL           0.815684                0.226735
# 11                ~NULL           1.003919                0.279059
# 12                ~NULL           0.334640                0.093020
# ...                 ...                ...                     ...
# 81805             ~NULL           1.160084                0.725553
# 81806             ~NULL           0.123413                0.077186
# 81807             ~NULL           0.128898                0.080617
# 81808             ~NULL           0.483369                0.302314
# 81809             ~NULL           0.322246                0.201542
#
#        gene_specificity_score  evidence_score
# 8                    1.798760             2.0
# 9                    1.798760             2.0
# 10                   1.798760             2.0
# 11                   1.798760             2.0
# 12                   1.798760             2.0
# ...                       ...             ...
# 81805                0.799449             2.0
# 81806                0.799449             2.0
# 81807                0.799449             2.0
# 81808                0.799449             2.0
# 81809                0.799449             2.0
#
# [6076 rows x 16 columns]

# %% [markdown]
# ## FILTER Namespaces

# %%
## genes

df["gene_prefix"] = [i.split(":")[0] for i in df["gene_concept_id"]]

df["gene_prefix"].value_counts()

## this is ENSG
df[df["gene_prefix"] == "ensembl"]
# Out:
# gene_prefix
# hgnc        80710
# ncbigene     1099
# ensembl         1
# Name: count, dtype: int64
#       gene_claim_name          gene_concept_id gene_name drug_claim_name  \
# 30352            TARP  ensembl:ENSG00000289746      TARP    TESTOSTERONE
#
#       drug_concept_id     drug_name drug_is_approved drug_is_immunotherapy  \
# 30352     rxcui:10379  TESTOSTERONE             True                 False
#
#       drug_is_antineoplastic interaction_source_db_name  \
# 30352                   True                        NCI
#
#       interaction_source_db_version interaction_types  interaction_score  \
# 30352             14-September-2017             ~NULL           4.015677
#
#        drug_specificity_score  gene_specificity_score  evidence_score  \
# 30352                 0.09302               14.390078             3.0
#
#       gene_prefix
# 30352     ensembl

# %%
## drugs

df["drug_prefix"] = [i.split(":")[0] for i in df["drug_concept_id"]]

df["drug_prefix"].value_counts()

df[df["drug_prefix"] == "chemidplus"]
# Out:
# drug_prefix
# rxcui             34787
# ncit              15105
# iuphar.ligand     15052
# chembl            12985
# drugbank           3724
# wikidata            112
# hemonc               30
# drugsatfda.nda       12
# chemidplus            3
# Name: count, dtype: int64
#                        gene_claim_name gene_concept_id gene_name  \
# 5553                            CYP7B1       hgnc:2652    CYP7B1
# 31674       NOREPINEPHRINE TRANSPORTER      hgnc:11048    SLC6A2
# 71908  ESTROGEN-RELATED RECEPTOR-ALPHA       hgnc:3471     ESRRA
#
#                drug_claim_name        drug_concept_id  \
# 5553                       DDD     chemidplus:72-54-8
# 31674                Hypericum  chemidplus:68917-49-7
# 71908  Dexamethasone palmitate  chemidplus:14899-36-6
#
#                      drug_name drug_is_approved drug_is_immunotherapy  \
# 5553                       TDE            False                 False
# 31674          ST. JOHN'S WORT            False                 False
# 71908  DEXAMETHASONE PALMITATE            False                 False
#
#       drug_is_antineoplastic interaction_source_db_name  \
# 5553                   False                        NCI
# 31674                  False                        TTD
# 71908                  False                        TTD
#
#       interaction_source_db_version interaction_types  interaction_score  \
# 5553              14-September-2017             ~NULL           6.960506
# 31674                    2020.06.01             ~NULL           0.483369
# 71908                    2020.06.01             ~NULL           8.700633
#
#        drug_specificity_score  gene_specificity_score  evidence_score  \
# 5553                 3.627763                0.959339             2.0
# 31674                3.627763                0.133241             1.0
# 71908                3.627763                2.398346             1.0
#
#       gene_prefix drug_prefix
# 5553         hgnc  chemidplus
# 31674        hgnc  chemidplus
# 71908        hgnc  chemidplus

# %% [markdown]
# **[NodeNorm](https://nodenormalization-sri.renci.org/1.5/get_curie_prefixes?semantic_type=biolink%3ANamedThing) can't handle:**
# * iuphar.ligand
# * wikidata
# * hemonc
# * drugsatfda.nda
# * chemidplus
#
# Notes:
# * assuming chembl = CHEMBL.COMPOUND. based on some spot-checks, it seems to work some of the time?)
# * Noticed some names are also not NameRes-able, ex: `COMPOUND 5 [PMID: 29579323]`

# %%
## NodeNorm doesn't recognize

PREFIXES_TO_DROP = [
    ## . probably will be treated as "all match"...unless escaped
    "iuphar\\.ligand",
    "wikidata",
    "hemonc",
    "drugsatfda\\.nda",
    "chemidplus",
]

# %%
## set case=False so it isn't case-sensitive on matches!

n_before = df.shape[0]
df = df[~df.drug_prefix.str.contains('|'.join(PREFIXES_TO_DROP), case=False)].copy()

## -> log
print(f"{df.shape[0]} rows ({df.shape[0] / n_before:.1%}) after filtering out drug prefixes that can't be NodeNormed")
# Out:
# 66601 rows (81.4%) after filtering out drug prefixes that can't be NodeNormed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66601 entries, 0 to 81809
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   gene_claim_name                66596 non-null  object
#  1   gene_concept_id                66601 non-null  object
#  2   gene_name                      66601 non-null  object
#  3   drug_claim_name                66601 non-null  object
#  4   drug_concept_id                66601 non-null  object
#  5   drug_name                      66601 non-null  object
#  6   drug_is_approved               66601 non-null  object
#  7   drug_is_immunotherapy          66601 non-null  object
#  8   drug_is_antineoplastic         66601 non-null  object
#  9   interaction_source_db_name     66601 non-null  object
#  10  interaction_source_db_version  66601 non-null  object
#  11  interaction_types              66601 non-null  object
#  12  interaction_score              66601 non-null  float64
#  13  drug_specificity_score         66601 non-null  float64
#  14  gene_specificity_score         66601 non-null  float64
#  15  evidence_score                 66601 non-null  float64
#  16  gene_prefix                    66601 non-null  object
#  17  drug_prefix                    66601 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 9.7+ MB

# %% [markdown]
# ## EDA drug_is_immunotherapy

# %% [markdown]
# Matt wanted to know if there was a relationship between this flag and the interaction_types

# %%
df["drug_is_immunotherapy"].value_counts()

## this looks like more than the "immune"-related interaction_types
# Out:
# drug_is_immunotherapy
# False    65287
# True      1314
# Name: count, dtype: int64

# %%
df[df["drug_is_immunotherapy"] == True]["interaction_types"].value_counts(dropna=False).sort_index()
# Out:
# interaction_types
# activator           1
# agonist            36
# antibody           83
# binder              3
# blocker             1
# immunotherapy      10
# inhibitor         128
# modulator           2
# ~NULL            1050
# Name: count, dtype: int64

# %%
df[df["drug_is_immunotherapy"] == False]["interaction_types"].value_counts(dropna=False).sort_index()
# Out:
# interaction_types
# activator                      280
# agonist                       2645
# antibody                        49
# antisense oligonucleotide        4
# binder                         254
# blocker                       1372
# cleavage                        83
# immunotherapy                    1
# inhibitor                    11759
# inverse agonist                 36
# modulator                      745
# negative modulator             132
# other/unknown                  215
# positive modulator            1010
# potentiator                     51
# vaccine                         31
# ~NULL                        46620
# Name: count, dtype: int64

# %% [markdown]
# **Summary**
#
# `drug_is_immunotherapy` is basically independent of `interaction_types`:
# * `True`: only a small subset have immune-related interaction_type (antibody, immunotherapy)
# * `False`: some immune-related interaction_type rows are here! (antibody, immunotherapy, vaccine)

# %% [markdown]
# ## EDA Merging by gene-drug pairs

# %%
## first drop some columns - not needed OR values won't make sense after merge
## makes merge faster

# cols_not_needed = [
#     "gene_claim_name", 
#     "drug_claim_name",
#     "interaction_source_db_version", 
#     "gene_prefix",
#     "drug_prefix",
# ]

# merge1 = df.drop(columns=cols_not_needed).copy()

# %%
## merge: takes ~10s to run

# cols_define_1 = ["gene_concept_id", "drug_concept_id"]

# merge1 = merge1.groupby(by=cols_define_1).agg(set).reset_index().copy()

# %%
# merge1.shape[0]

# merge1
# Out:
# 55077
#                gene_concept_id       drug_concept_id  gene_name  \
# 0      ensembl:ENSG00000289746           rxcui:10379     {TARP}
# 1                     hgnc:100         rxcui:1148138    {ASIC1}
# 2                     hgnc:100             rxcui:644    {ASIC1}
# 3                   hgnc:10000   chembl:CHEMBL107131     {RGS4}
# 4                   hgnc:10000  chembl:CHEMBL1255835     {RGS4}
# ...                        ...                   ...        ...
# 55072               ncbigene:7            rxcui:8332    {A12M4}
# 55073               ncbigene:7            rxcui:8353    {A12M4}
# 55074             ncbigene:849          ncit:C152542  {CATHL1L}
# 55075             ncbigene:849         rxcui:1294569  {CATHL1L}
# 55076             ncbigene:849            rxcui:7646  {CATHL1L}
#
#                    drug_name drug_is_approved drug_is_immunotherapy  \
# 0             {TESTOSTERONE}           {True}               {False}
# 1                {ICATIBANT}           {True}               {False}
# 2                {AMILORIDE}           {True}               {False}
# 3      {DIMETHYLPINOCEMBRIN}          {False}               {False}
# 4                  {DIAMIDE}          {False}               {False}
# ...                      ...              ...                   ...
# 55072             {PINDOLOL}           {True}               {False}
# 55073            {PIRIBEDIL}          {False}               {False}
# 55074           {TEGOPRAZAN}          {False}               {False}
# 55075  {ESOMEPRAZOLE SODIUM}           {True}               {False}
# 55076           {OMEPRAZOLE}           {True}               {False}
#
#       drug_is_antineoplastic interaction_source_db_name     interaction_types  \
# 0                     {True}                      {NCI}               {~NULL}
# 1                     {True}      {GuideToPharmacology}           {inhibitor}
# 2                     {True}                      {TTD}               {~NULL}
# 3                    {False}                      {DTC}               {~NULL}
# 4                    {False}                      {DTC}               {~NULL}
# ...                      ...                        ...                   ...
# 55072                 {True}      {GuideToPharmacology}  {inhibitor, agonist}
# 55073                 {True}      {GuideToPharmacology}           {inhibitor}
# 55074                 {True}      {GuideToPharmacology}           {inhibitor}
# 55075                 {True}      {GuideToPharmacology}           {inhibitor}
# 55076                 {True}      {GuideToPharmacology}           {inhibitor}
#
#           interaction_score drug_specificity_score gene_specificity_score  \
# 0       {4.015676812221963}     {0.09301957340359}   {14.390078221490326}
# 1      {0.6868920863011254}   {1.8138816813700047}   {0.3786862689865875}
# 2      {0.0808108336824853}   {0.2133978448670594}   {0.3786862689865875}
# 3      {0.1706006488852468}     {1.20925445424667}   {0.1410791982499051}
# 4      {0.0853003244426234}    {0.604627227123335}   {0.1410791982499051}
# ...                     ...                    ...                    ...
# 55072  {0.0610570743378778}   {0.4030848180822233}    {0.151474507594635}
# 55073  {0.0457928057534083}   {0.3023136135616675}    {0.151474507594635}
# 55074   {5.800422062098392}     {1.20925445424667}    {4.796692740496775}
# 55075   {2.900211031049196}    {0.604627227123335}    {4.796692740496775}
# 55076  {0.4703044915214913}   {0.0980476584524327}    {4.796692740496775}
#
#       evidence_score
# 0              {3.0}
# 1              {1.0}
# 2              {1.0}
# 3              {1.0}
# 4              {1.0}
# ...              ...
# 55072          {1.0}
# 55073          {1.0}
# 55074          {1.0}
# 55075          {1.0}
# 55076          {1.0}
#
# [55077 rows x 13 columns]

# %%
## all single values - so same for a gene-drug pair

# ## tied to gene
# merge1[merge1["gene_name"].map(len) > 1].shape[0]

# ## tied to drug, basically a node attribute/annotation
# merge1[merge1["drug_name"].map(len) > 1].shape[0]
# merge1[merge1["drug_is_approved"].map(len) > 1].shape[0]
# merge1[merge1["drug_is_immunotherapy"].map(len) > 1].shape[0]
# merge1[merge1["drug_is_antineoplastic"].map(len) > 1].shape[0]
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
## all single values - so same for a gene-drug pair

# ## scores for gene-drug pair
# merge1[merge1["interaction_score"].map(len) > 1].shape[0]
# merge1[merge1["evidence_score"].map(len) > 1].shape[0]

# ## scores for only drug or only gene
# merge1[merge1["drug_specificity_score"].map(len) > 1].shape[0]
# merge1[merge1["gene_specificity_score"].map(len) > 1].shape[0]
# Out:
# 0
# 0
# 0
# 0

# %%
## end up with multiple values 

# merge1[merge1["interaction_types"].map(len) > 1].shape[0]

# merge1[merge1["interaction_source_db_name"].map(len) > 1].shape[0]
# Out:
# 3692
# 5982

# %% [markdown]
# ### interaction_types

# %% [markdown]
# **6.7%** of the dataset has **multiple interaction_types from the merge**.
#
# Are there sets that don't make sense?

# %%
# merge1_multi_types = merge1[merge1["interaction_types"].map(len) > 1].copy()

# print(f"{merge1_multi_types.shape[0] / merge1.shape[0]:.2%}")

# merge1_multi_types
# Out:
# 6.70%
#       gene_concept_id drug_concept_id   gene_name              drug_name  \
# 87         hgnc:10009    ncit:C152241       {RHD}            {ROLEDUMAB}
# 140         hgnc:1014   rxcui:1364347       {BCR}            {PONATINIB}
# 141         hgnc:1014   rxcui:1546019       {BCR}  {DASATINIB ANHYDROUS}
# 149         hgnc:1014    rxcui:282388       {BCR}             {IMATINIB}
# 158         hgnc:1024     rxcui:10324  {BCYRN1P2}            {TAMOXIFEN}
# ...               ...             ...         ...                    ...
# 54654       hgnc:9967    rxcui:357977       {RET}            {SUNITINIB}
# 54656       hgnc:9967    rxcui:495881       {RET}            {SORAFENIB}
# 54943      ncbigene:6    rxcui:221153     {A12M3}  {QUETIAPINE FUMARATE}
# 54972      ncbigene:6      rxcui:8332     {A12M3}             {PINDOLOL}
# 55072      ncbigene:7      rxcui:8332     {A12M4}             {PINDOLOL}
#
#       drug_is_approved drug_is_immunotherapy drug_is_antineoplastic  \
# 87             {False}               {False}                 {True}
# 140             {True}               {False}                 {True}
# 141             {True}               {False}                 {True}
# 149             {True}               {False}                 {True}
# 158             {True}               {False}                 {True}
# ...                ...                   ...                    ...
# 54654           {True}               {False}                 {True}
# 54656           {True}               {False}                 {True}
# 54943           {True}               {False}                 {True}
# 54972           {True}               {False}                 {True}
# 55072           {True}               {False}                 {True}
#
#                                                                     interaction_source_db_name  \
# 87                                                                               {ChEMBL, TTD}
# 140                                                              {FDA, ChEMBL, TALC, PharmGKB}
# 141                                                              {FDA, ChEMBL, TALC, PharmGKB}
# 149                                                         {ChEMBL, DTC, TALC, FDA, PharmGKB}
# 158                                                                      {GuideToPharmacology}
# ...                                                                                        ...
# 54654  {ChEMBL, TdgClinicalTrial, CGI, CKB-CORE, TEND, DoCM, MyCancerGenome, TALC, NCI, CIViC}
# 54656                            {ChEMBL, DTC, CKB-CORE, MyCancerGenome, NCI, PharmGKB, CIViC}
# 54943                                                                    {GuideToPharmacology}
# 54972                                                                    {GuideToPharmacology}
# 55072                                                                    {GuideToPharmacology}
#
#           interaction_types     interaction_score drug_specificity_score  \
# 87       {inhibitor, ~NULL}   {26.10189927944276}   {3.6277633627400094}
# 140      {inhibitor, ~NULL}  {0.3650615283838149}    {0.139529360105385}
# 141      {inhibitor, ~NULL}  {0.1248894702365682}   {0.0477337284571054}
# 149      {inhibitor, ~NULL}  {0.2306986047425497}   {0.0503856022602779}
# 158    {inhibitor, agonist}  {0.0243374352255876}    {0.055811744042154}
# ...                     ...                   ...                    ...
# 54654    {inhibitor, ~NULL}  {0.3978948060890666}   {0.0755784033904168}
# 54656    {inhibitor, ~NULL}  {0.0719670605795877}   {0.0315457683716522}
# 54943  {inhibitor, agonist}  {0.0111546578117276}   {0.1007712045205558}
# 54972  {inhibitor, agonist}  {0.0446186312469107}   {0.4030848180822233}
# 55072  {inhibitor, agonist}  {0.0610570743378778}   {0.4030848180822233}
#
#       gene_specificity_score evidence_score
# 87      {3.5975195553725814}          {2.0}
# 140     {0.6540944646131966}          {4.0}
# 141     {0.6540944646131966}          {4.0}
# 149     {0.6540944646131966}          {7.0}
# 158     {0.4360629764087977}          {1.0}
# ...                      ...            ...
# 54654   {0.1754887587986625}         {30.0}
# 54656   {0.1754887587986625}         {13.0}
# 54943   {0.1106929093960794}          {1.0}
# 54972   {0.1106929093960794}          {1.0}
# 55072    {0.151474507594635}          {1.0}
#
# [3692 rows x 13 columns]

# %%
# SORT values first - so the sets are ideally unique beforehand

# merge1_multi_types["interaction_types"] = [",".join(sorted(i)) for i in merge1_multi_types["interaction_types"]]

# %%
# merge1_multi_types["interaction_types"].nunique()
# Out:
# 47

# %%
# merge1_multi_types["interaction_types"].value_counts(normalize=True)
# Out:
# interaction_types
# inhibitor,~NULL                                   0.604009
# agonist,~NULL                                     0.147616
# positive modulator,~NULL                          0.089653
# blocker,~NULL                                     0.029252
# binder,~NULL                                      0.023294
# inhibitor,other/unknown,~NULL                     0.022752
# modulator,~NULL                                   0.019772
# antibody,inhibitor,~NULL                          0.008938
# other/unknown,~NULL                               0.007313
# activator,~NULL                                   0.006501
# agonist,inhibitor                                 0.004063
# negative modulator,~NULL                          0.003792
# blocker,inhibitor                                 0.003250
# potentiator,~NULL                                 0.002709
# cleavage,~NULL                                    0.002438
# modulator,positive modulator,~NULL                0.002167
# vaccine,~NULL                                     0.002167
# inhibitor,modulator,~NULL                         0.002167
# antibody,inhibitor                                0.001896
# inhibitor,other/unknown                           0.001625
# inverse agonist,~NULL                             0.001354
# antibody,immunotherapy,inhibitor,~NULL            0.001083
# agonist,antibody,~NULL                            0.001083
# agonist,antibody                                  0.001083
# antibody,~NULL                                    0.001083
# antibody,binder,~NULL                             0.000813
# activator,potentiator,~NULL                       0.000813
# agonist,inhibitor,~NULL                           0.000542
# immunotherapy,inhibitor,~NULL                     0.000542
# blocker,negative modulator                        0.000542
# antibody,modulator,~NULL                          0.000542
# modulator,negative modulator,~NULL                0.000542
# agonist,modulator                                 0.000542
# blocker,inhibitor,~NULL                           0.000542
# activator,inhibitor,~NULL                         0.000271
# activator,blocker                                 0.000271
# cleavage,inhibitor,~NULL                          0.000271
# blocker,modulator                                 0.000271
# agonist,immunotherapy,~NULL                       0.000271
# antibody,immunotherapy                            0.000271
# activator,positive modulator,~NULL                0.000271
# modulator,positive modulator                      0.000271
# blocker,negative modulator,~NULL                  0.000271
# inhibitor,inverse agonist,~NULL                   0.000271
# antibody,immunotherapy,~NULL                      0.000271
# antibody,immunotherapy,inhibitor                  0.000271
# antibody,blocker,immunotherapy,inhibitor,~NULL    0.000271
# Name: proportion, dtype: float64

# %% [markdown]
# Top are (cover >82%):
# * `inhibitor,~NULL` (60%)
# * `agonist,~NULL` (>14%)
# * `positive modulator,~NULL` (>8%)

# %%
# merge1_multi_types["interaction_types"].value_counts().sort_index()
# Out:
# interaction_types
# activator,blocker                                    1
# activator,inhibitor,~NULL                            1
# activator,positive modulator,~NULL                   1
# activator,potentiator,~NULL                          3
# activator,~NULL                                     24
# agonist,antibody                                     4
# agonist,antibody,~NULL                               4
# agonist,immunotherapy,~NULL                          1
# agonist,inhibitor                                   15
# agonist,inhibitor,~NULL                              2
# agonist,modulator                                    2
# agonist,~NULL                                      545
# antibody,binder,~NULL                                3
# antibody,blocker,immunotherapy,inhibitor,~NULL       1
# antibody,immunotherapy                               1
# antibody,immunotherapy,inhibitor                     1
# antibody,immunotherapy,inhibitor,~NULL               4
# antibody,immunotherapy,~NULL                         1
# antibody,inhibitor                                   7
# antibody,inhibitor,~NULL                            33
# antibody,modulator,~NULL                             2
# antibody,~NULL                                       4
# binder,~NULL                                        86
# blocker,inhibitor                                   12
# blocker,inhibitor,~NULL                              2
# blocker,modulator                                    1
# blocker,negative modulator                           2
# blocker,negative modulator,~NULL                     1
# blocker,~NULL                                      108
# cleavage,inhibitor,~NULL                             1
# cleavage,~NULL                                       9
# immunotherapy,inhibitor,~NULL                        2
# inhibitor,inverse agonist,~NULL                      1
# inhibitor,modulator,~NULL                            8
# inhibitor,other/unknown                              6
# inhibitor,other/unknown,~NULL                       84
# inhibitor,~NULL                                   2230
# inverse agonist,~NULL                                5
# modulator,negative modulator,~NULL                   2
# modulator,positive modulator                         1
# modulator,positive modulator,~NULL                   8
# modulator,~NULL                                     73
# negative modulator,~NULL                            14
# other/unknown,~NULL                                 27
# positive modulator,~NULL                           331
# potentiator,~NULL                                   10
# vaccine,~NULL                                        8
# Name: count, dtype: int64

# %% [markdown]
# **MERGED DATA ISSUES**
#
# (fully reviewed)
#
# **Opposing**
# * **agonist,inhibitor**
#
# **Makes sense, but tricky to merge? (1 example of each kind)**
# * activator,potentiator,~NULL
# * **agonist,antibody**
# * antibody,binder,~NULL
# * antibody,blocker,immunotherapy,inhibitor,~NULL
# * antibody,inhibitor
# * blocker,inhibitor
# * **cleavage,inhibitor,~NULL**
# * inhibitor,inverse agonist,~NULL

# %%
# merge1_multi_types[merge1_multi_types["interaction_types"] == "agonist,antibody"]
# Out:
#      gene_concept_id       drug_concept_id    gene_name     drug_name  \
# 5678      hgnc:11904            ncit:C1685  {TNFRSF10A}  {DULANERMIN}
# 5681      hgnc:11905  chembl:CHEMBL2109247  {TNFRSF10B}     {LBY-135}
# 5684      hgnc:11905            ncit:C1685  {TNFRSF10B}  {DULANERMIN}
# 5688      hgnc:11905           ncit:C71693  {TNFRSF10B}      {APOMAB}
#
#      drug_is_approved drug_is_immunotherapy drug_is_antineoplastic  \
# 5678          {False}                {True}                 {True}
# 5681          {False}                {True}                 {True}
# 5684          {False}                {True}                 {True}
# 5688          {False}                {True}                 {True}
#
#           interaction_source_db_name interaction_types    interaction_score  \
# 5678  {ChEMBL, TALC, MyCancerGenome}  agonist,antibody  {15.66113956766565}
# 5681  {ChEMBL, TALC, MyCancerGenome}  agonist,antibody  {17.40126618629517}
# 5684  {ChEMBL, TALC, MyCancerGenome}  agonist,antibody  {8.700633093147589}
# 5688        {ChEMBL, MyCancerGenome}  agonist,antibody  {11.60084412419678}
#
#      drug_specificity_score gene_specificity_score evidence_score
# 5678   {1.8138816813700047}    {2.878015644298065}          {3.0}
# 5681   {3.6277633627400094}   {1.5988975801655918}          {3.0}
# 5684   {1.8138816813700047}   {1.5988975801655918}          {3.0}
# 5688   {3.6277633627400094}   {1.5988975801655918}          {2.0}

# %%
rows_with_plain = merge1_multi_types[merge1_multi_types["interaction_types"].str.contains("NULL|other")].copy()


print(f"{rows_with_plain.shape[0] / merge1_multi_types.shape[0]:.2%}")
# Out:
# 98.78%

# %% [markdown]
# ### interaction_source_db_name

# %% [markdown]
# **10.8%** of data has multiple sources after merge
#
# EDA only

# %%
# merge1_multi_sources = merge1[merge1["interaction_source_db_name"].map(len) > 1].copy()

# print(f"{merge1_multi_sources.shape[0] / merge1.shape[0]:.2%}")

# merge1_multi_sources
# Out:
# 10.86%
#       gene_concept_id drug_concept_id gene_name              drug_name  \
# 87         hgnc:10009    ncit:C152241     {RHD}            {ROLEDUMAB}
# 137         hgnc:1014     rxcui:11202     {BCR}          {VINCRISTINE}
# 138         hgnc:1014   rxcui:1307619     {BCR}            {BOSUTINIB}
# 140         hgnc:1014   rxcui:1364347     {BCR}            {PONATINIB}
# 141         hgnc:1014   rxcui:1546019     {BCR}  {DASATINIB ANHYDROUS}
# ...               ...             ...       ...                    ...
# 54646       hgnc:9967   rxcui:2370147     {RET}        {SELPERCATINIB}
# 54647       hgnc:9967   rxcui:2394936     {RET}          {PRALSETINIB}
# 54651       hgnc:9967    rxcui:282388     {RET}             {IMATINIB}
# 54654       hgnc:9967    rxcui:357977     {RET}            {SUNITINIB}
# 54656       hgnc:9967    rxcui:495881     {RET}            {SORAFENIB}
#
#       drug_is_approved drug_is_immunotherapy drug_is_antineoplastic  \
# 87             {False}               {False}                 {True}
# 137             {True}               {False}                 {True}
# 138             {True}               {False}                 {True}
# 140             {True}               {False}                 {True}
# 141             {True}               {False}                 {True}
# ...                ...                   ...                    ...
# 54646           {True}               {False}                 {True}
# 54647           {True}               {False}                 {True}
# 54651           {True}               {False}                 {True}
# 54654           {True}               {False}                 {True}
# 54656           {True}               {False}                 {True}
#
#                                                                     interaction_source_db_name  \
# 87                                                                               {ChEMBL, TTD}
# 137                                                                            {FDA, PharmGKB}
# 138                                                                            {FDA, PharmGKB}
# 140                                                              {FDA, ChEMBL, TALC, PharmGKB}
# 141                                                              {FDA, ChEMBL, TALC, PharmGKB}
# ...                                                                                        ...
# 54646                                         {ChEMBL, CKB-CORE, OncoKB, PharmGKB, TTD, CIViC}
# 54647                                         {ChEMBL, CKB-CORE, OncoKB, PharmGKB, TTD, CIViC}
# 54651                                                            {TdgClinicalTrial, TEND, NCI}
# 54654  {ChEMBL, TdgClinicalTrial, CGI, CKB-CORE, TEND, DoCM, MyCancerGenome, TALC, NCI, CIViC}
# 54656                            {ChEMBL, DTC, CKB-CORE, MyCancerGenome, NCI, PharmGKB, CIViC}
#
#         interaction_types     interaction_score drug_specificity_score  \
# 87     {inhibitor, ~NULL}   {26.10189927944276}   {3.6277633627400094}
# 137               {~NULL}  {0.0585901218393777}   {0.0447872020091359}
# 138               {~NULL}   {0.206339124738678}   {0.1577288418582613}
# 140    {inhibitor, ~NULL}  {0.3650615283838149}    {0.139529360105385}
# 141    {inhibitor, ~NULL}  {0.1248894702365682}   {0.0477337284571054}
# ...                   ...                   ...                    ...
# 54646  {inhibitor, ~NULL}   {5.411369362811306}   {0.9069408406850026}
# 54647  {inhibitor, ~NULL}   {2.000842453476449}   {0.5182519089628587}
# 54651             {~NULL}   {0.035368427207917}   {0.0503856022602779}
# 54654  {inhibitor, ~NULL}  {0.3978948060890666}   {0.0755784033904168}
# 54656  {inhibitor, ~NULL}  {0.0719670605795877}   {0.0315457683716522}
#
#       gene_specificity_score evidence_score
# 87      {3.5975195553725814}          {2.0}
# 137     {0.6540944646131966}          {2.0}
# 138     {0.6540944646131966}          {2.0}
# 140     {0.6540944646131966}          {4.0}
# 141     {0.6540944646131966}          {4.0}
# ...                      ...            ...
# 54646   {0.1754887587986625}         {34.0}
# 54647   {0.1754887587986625}         {22.0}
# 54651   {0.1754887587986625}          {4.0}
# 54654   {0.1754887587986625}         {30.0}
# 54656   {0.1754887587986625}         {13.0}
#
# [5982 rows x 13 columns]

# %%
# SORT values first - so the sets are ideally unique beforehand

# merge1_multi_sources["interaction_source_db_name"] = [",".join(sorted(i)) for i in merge1_multi_sources["interaction_source_db_name"]]

# %%
# merge1_multi_sources["interaction_source_db_name"].nunique()
# Out:
# 640

# %%
# merge1_multi_sources["interaction_source_db_name"].value_counts()[0:10]
# Out:
# interaction_source_db_name
# ChEMBL,TTD                          782
# TEND,TdgClinicalTrial               767
# ChEMBL,TEND,TdgClinicalTrial        515
# ChEMBL,TdgClinicalTrial             402
# ChEMBL,TEND,TTD,TdgClinicalTrial    249
# ChEMBL,TTD,TdgClinicalTrial         220
# TEND,TTD,TdgClinicalTrial           180
# FDA,PharmGKB                        180
# ChEMBL,DTC                          155
# TTD,TdgClinicalTrial                155
# Name: count, dtype: int64

# %% [markdown]
# ## EDA Merging by gene-drug-interaction_type sets

# %%
# ## first drop some columns - not needed OR values won't make sense after merge
# ## makes merge faster

# ## and order for readability
# merge2 = df[["drug_concept_id", "drug_name", 
#              "gene_concept_id", "gene_name",
#              "interaction_types", "interaction_source_db_name",
#              "interaction_score", "evidence_score"
#             ]].copy()

# %%
# ## merge: takes ~5s to run

# cols_define_edge_2 = ["gene_concept_id", "drug_concept_id", "interaction_types"]

# merge2 = merge2.groupby(by=cols_define_edge_2).agg(set).reset_index().copy()

# %%
# merge2.shape[0]

# merge2
# Out:
# 58941
#                gene_concept_id       drug_concept_id interaction_types  \
# 0      ensembl:ENSG00000289746           rxcui:10379             ~NULL
# 1                     hgnc:100         rxcui:1148138         inhibitor
# 2                     hgnc:100             rxcui:644             ~NULL
# 3                   hgnc:10000   chembl:CHEMBL107131             ~NULL
# 4                   hgnc:10000  chembl:CHEMBL1255835             ~NULL
# ...                        ...                   ...               ...
# 58936               ncbigene:7            rxcui:8332         inhibitor
# 58937               ncbigene:7            rxcui:8353         inhibitor
# 58938             ncbigene:849          ncit:C152542         inhibitor
# 58939             ncbigene:849         rxcui:1294569         inhibitor
# 58940             ncbigene:849            rxcui:7646         inhibitor
#
#                    drug_name  gene_name interaction_source_db_name  \
# 0             {TESTOSTERONE}     {TARP}                      {NCI}
# 1                {ICATIBANT}    {ASIC1}      {GuideToPharmacology}
# 2                {AMILORIDE}    {ASIC1}                      {TTD}
# 3      {DIMETHYLPINOCEMBRIN}     {RGS4}                      {DTC}
# 4                  {DIAMIDE}     {RGS4}                      {DTC}
# ...                      ...        ...                        ...
# 58936             {PINDOLOL}    {A12M4}      {GuideToPharmacology}
# 58937            {PIRIBEDIL}    {A12M4}      {GuideToPharmacology}
# 58938           {TEGOPRAZAN}  {CATHL1L}      {GuideToPharmacology}
# 58939  {ESOMEPRAZOLE SODIUM}  {CATHL1L}      {GuideToPharmacology}
# 58940           {OMEPRAZOLE}  {CATHL1L}      {GuideToPharmacology}
#
#           interaction_score
# 0       {4.015676812221963}
# 1      {0.6868920863011254}
# 2      {0.0808108336824853}
# 3      {0.1706006488852468}
# 4      {0.0853003244426234}
# ...                     ...
# 58936  {0.0610570743378778}
# 58937  {0.0457928057534083}
# 58938   {5.800422062098392}
# 58939   {2.900211031049196}
# 58940  {0.4703044915214913}
#
# [58941 rows x 7 columns]

# %%
# ## how many rows with "duplicate" drug-gene pairs

# merge2_samepair = merge2[merge2.duplicated(subset=["gene_concept_id", "drug_concept_id"], keep=False)].copy()

# merge2_samepair.shape[0]
# Out:
# 7556

# %%
# merge2_samepair[40:61]
# Out:
#      gene_concept_id   drug_concept_id interaction_types  \
# 412        hgnc:1030     rxcui:1148138         inhibitor
# 413        hgnc:1030     rxcui:1148138             ~NULL
# 553        hgnc:1033     rxcui:1005920           agonist
# 554        hgnc:1033     rxcui:1005920         inhibitor
# 617        hgnc:1033        rxcui:6964           agonist
# 618        hgnc:1033        rxcui:6964         inhibitor
# 619        hgnc:1033        rxcui:6964             ~NULL
# 996       hgnc:10436  drugbank:DB12690         inhibitor
# 997       hgnc:10436  drugbank:DB12690             ~NULL
# 998       hgnc:10436  drugbank:DB15431         inhibitor
# 999       hgnc:10436  drugbank:DB15431             ~NULL
# 1039      hgnc:10451        ncit:C1881         inhibitor
# 1040      hgnc:10451        ncit:C1881             ~NULL
# 1042      hgnc:10451       rxcui:12574         inhibitor
# 1043      hgnc:10451       rxcui:12574             ~NULL
# 1044      hgnc:10451       rxcui:24698         inhibitor
# 1045      hgnc:10451       rxcui:24698             ~NULL
# 1052      hgnc:10451       rxcui:44151         inhibitor
# 1053      hgnc:10451       rxcui:44151             ~NULL
# 1055      hgnc:10451        rxcui:5552         inhibitor
# 1056      hgnc:10451        rxcui:5552             ~NULL
#
#                    drug_name  gene_name  \
# 412              {ICATIBANT}   {BDKRB2}
# 413              {ICATIBANT}   {BDKRB2}
# 553     {ULIPRISTAL ACETATE}     {BDNF}
# 554     {ULIPRISTAL ACETATE}     {BDNF}
# 617           {MIFEPRISTONE}     {BDNF}
# 618           {MIFEPRISTONE}     {BDNF}
# 619           {MIFEPRISTONE}     {BDNF}
# 996             {LY-2584702}  {RPS6KB1}
# 997             {LY-2584702}  {RPS6KB1}
# 998                 {M-2698}  {RPS6KB1}
# 999                 {M-2698}  {RPS6KB1}
# 1039  {MOTEXAFIN GADOLINIUM}     {RRM1}
# 1040  {MOTEXAFIN GADOLINIUM}     {RRM1}
# 1042           {GEMCITABINE}     {RRM1}
# 1043           {GEMCITABINE}     {RRM1}
# 1044           {FLUDARABINE}     {RRM1}
# 1045           {FLUDARABINE}     {RRM1}
# 1052           {CLOFARABINE}     {RRM1}
# 1053           {CLOFARABINE}     {RRM1}
# 1055           {HYDROXYUREA}     {RRM1}
# 1056           {HYDROXYUREA}     {RRM1}
#
#                                         interaction_source_db_name  \
# 412                                          {GuideToPharmacology}
# 413                                  {TdgClinicalTrial, TEND, TTD}
# 553                                          {GuideToPharmacology}
# 554                                          {GuideToPharmacology}
# 617                                          {GuideToPharmacology}
# 618                                          {GuideToPharmacology}
# 619                                                          {NCI}
# 996                                                       {ChEMBL}
# 997                                                          {TTD}
# 998                                                       {ChEMBL}
# 999                                                          {TTD}
# 1039                                                      {ChEMBL}
# 1040                                            {TdgClinicalTrial}
# 1042                     {ChEMBL, ClearityFoundationClinicalTrial}
# 1043  {TdgClinicalTrial, ClearityFoundationBiomarkers, CIViC, DTC}
# 1044                                                      {ChEMBL}
# 1045                                      {TdgClinicalTrial, TEND}
# 1052                                                      {ChEMBL}
# 1053                                      {TdgClinicalTrial, TEND}
# 1055                                                      {ChEMBL}
# 1056                                      {TdgClinicalTrial, TEND}
#
#          interaction_score
# 412    {2.175158273286897}
# 413    {2.175158273286897}
# 553   {0.2122105632475021}
# 554   {0.2122105632475021}
# 617   {0.0454736921244647}
# 618   {0.0454736921244647}
# 619   {0.0454736921244647}
# 996    {2.821826949128947}
# 997    {2.821826949128947}
# 998   {0.3135363276809941}
# 999   {0.3135363276809941}
# 1039  {0.8773747656955552}
# 1040  {0.8773747656955552}
# 1042  {0.2336487147776206}
# 1043  {0.2336487147776206}
# 1044  {0.2709539717589214}
# 1045  {0.2709539717589214}
# 1052   {0.484865002094912}
# 1053   {0.484865002094912}
# 1055  {0.4386873828477775}
# 1056  {0.4386873828477775}

# %% [markdown]
# Based on spot-check, don't see cases where the `~NULL` has the same sources as its "dup" row...
#
# `[44:47]` is a set of 3
#
# `.loc[56285:56287]` is a set of 3 with other/unknown and NULL

# %%
# ## looking for "other/unknown stuff"
# merge2_samepair[merge2_samepair["interaction_types"].str.contains("other")]
# Out:
#       gene_concept_id drug_concept_id interaction_types  \
# 3691       hgnc:11048    rxcui:221138     other/unknown
# 3705       hgnc:11048      rxcui:3287     other/unknown
# 3746       hgnc:11048      rxcui:8896     other/unknown
# 3750       hgnc:11048     rxcui:91239     other/unknown
# 3799       hgnc:11049      rxcui:3287     other/unknown
# ...               ...             ...               ...
# 56286       hgnc:9565   rxcui:1302966     other/unknown
# 56291       hgnc:9565    rxcui:358258     other/unknown
# 56296       hgnc:9566   rxcui:1302966     other/unknown
# 56301       hgnc:9566    rxcui:358258     other/unknown
# 56329       hgnc:9585   rxcui:1242987     other/unknown
#
#                          drug_name gene_name interaction_source_db_name  \
# 3691           {PHENTERMINE RESIN}  {SLC6A2}                   {ChEMBL}
# 3705   {DEXTROAMPHETAMINE SULFATE}  {SLC6A2}                   {ChEMBL}
# 3746             {PSEUDOEPHEDRINE}  {SLC6A2}                   {ChEMBL}
# 3750           {GUANADREL SULFATE}  {SLC6A2}                   {ChEMBL}
# 3799   {DEXTROAMPHETAMINE SULFATE}  {SLC6A3}                   {ChEMBL}
# ...                            ...       ...                        ...
# 56286                {CARFILZOMIB}   {PSMD7}           {MyCancerGenome}
# 56291                 {BORTEZOMIB}   {PSMD7}           {MyCancerGenome}
# 56296                {CARFILZOMIB}   {PSMD8}           {MyCancerGenome}
# 56301                 {BORTEZOMIB}   {PSMD8}           {MyCancerGenome}
# 56329                 {VISMODEGIB}   {PTCH1}           {MyCancerGenome}
#
#           interaction_score
# 3691   {0.6444913402331547}
# 3705   {0.0508808952815648}
# 3746   {0.0568668829617489}
# 3750   {0.7250527577622989}
# 3799   {0.3496905166623911}
# ...                     ...
# 56286  {0.4971790338941479}
# 56291   {0.350949906278222}
# 56296  {0.5800422062098393}
# 56301  {0.4094415573245924}
# 56329   {19.57642445958207}
#
# [128 rows x 7 columns]

# %%
# merge2_samepair.loc[56285:56287]
# Out:
#       gene_concept_id drug_concept_id interaction_types      drug_name  \
# 56285       hgnc:9565   rxcui:1302966         inhibitor  {CARFILZOMIB}
# 56286       hgnc:9565   rxcui:1302966     other/unknown  {CARFILZOMIB}
# 56287       hgnc:9565   rxcui:1302966             ~NULL  {CARFILZOMIB}
#
#       gene_name interaction_source_db_name     interaction_score
# 56285   {PSMD7}                   {ChEMBL}  {0.4971790338941479}
# 56286   {PSMD7}           {MyCancerGenome}  {0.4971790338941479}
# 56287   {PSMD7}                      {DTC}  {0.4971790338941479}

# %% [markdown]
# ## Experimental

# %%
## only including necessary columns 
##   + drug/gene names for readability/comparsion with website
## dropping columns makes merge faster

## order for readability
experiment_setup = df[["drug_concept_id", "drug_name", 
                       "gene_concept_id", "gene_name",
                       "interaction_types", "interaction_source_db_name",
                       "interaction_score", "evidence_score"
                      ]].copy()

# %% [markdown]
# **FIRST map interaction_types for "plain interacts_with" to 1 term -> "~PLAIN"**
#
# **Make new column and use it going forward - mod_type** (but in notebook, keep original so can check):
# * If "other/unknown" or "~NULL", put "~PLAIN"
# * Else keep original value
#
# Reasoning:
# * then when they both occur for same drug-gene pair, their rows can be merged
#   * All other interaction_types map to diff predicate/qualifier-sets so they don't need merging later (confirmed 11/18 night)
# * makes following logic easier: detecting "only one edge" or "plain interacts_with edge"
# * Other option is to map everything to predicate/qualifier-sets, then do logic with predicate/qualifier-sets. But I think that's more complicated to check…

# %%
plain_types = {"other/unknown", "~NULL"}

experiment_setup["mod_type"] = ["~PLAIN" if i in plain_types else i for i in experiment_setup["interaction_types"]]

# %%
## check how it looks

## regular: don't use "other" because "immunOTHERapy"
experiment_setup[experiment_setup["interaction_types"].str.contains("unknown|NULL")].shape[0]

## modded
experiment_setup[experiment_setup["mod_type"] == "~PLAIN"].shape[0]
# Out:
# 47885
# 47885

# %%
## more checks how it looks
experiment_setup[experiment_setup["mod_type"] == "~PLAIN"]["interaction_types"].unique()

experiment_setup[~ (experiment_setup["mod_type"] == "~PLAIN")]["interaction_types"].unique()
# Out:
# array(['~NULL', 'other/unknown'], dtype=object)
# array(['inhibitor', 'modulator', 'cleavage', 'blocker', 'binder',
#        'agonist', 'activator', 'positive modulator', 'vaccine',
#        'antibody', 'immunotherapy', 'negative modulator', 'potentiator',
#        'inverse agonist', 'antisense oligonucleotide'], dtype=object)

# %%
## group by drug ID, gene ID, mod_type combo

## saving in diff variable in case I want to still work with no-grouping-done later
experiment_mergeMain = experiment_setup.copy()

## merge: takes ~8s to run
cols_define_edge_3 = ["drug_concept_id", "gene_concept_id", "mod_type"]

## when it can be multiple values, run set
## otherwise, the value is always the same (from EDA), so just keep the first
experiment_mergeMain = experiment_mergeMain.groupby(by=cols_define_edge_3).agg(
    {
        "interaction_types": set, 
        "interaction_source_db_name": set,
        "interaction_score": 'first',
        "evidence_score": 'first',
        "drug_name": 'first',
        "gene_name": 'first',

    }
).reset_index().copy()

# %%
experiment_mergeMain.shape[0]
# Out:
# 58830

# %%
## check what rows look like with both original ~PLAIN values

experiment_mergeMain[experiment_mergeMain["gene_concept_id"] == "hgnc:9565"]
# Out:
#         drug_concept_id gene_concept_id   mod_type       interaction_types  \
# 15852  drugbank:DB16741       hgnc:9565  inhibitor             {inhibitor}
# 22106        ncit:C2160       hgnc:9565     ~PLAIN                 {~NULL}
# 29335       ncit:C91388       hgnc:9565  inhibitor             {inhibitor}
# 34091     rxcui:1302966       hgnc:9565  inhibitor             {inhibitor}
# 34092     rxcui:1302966       hgnc:9565     ~PLAIN  {other/unknown, ~NULL}
# 38207     rxcui:1723734       hgnc:9565  inhibitor             {inhibitor}
# 38249     rxcui:1723735       hgnc:9565  inhibitor             {inhibitor}
# 49417      rxcui:358258       hgnc:9565  inhibitor             {inhibitor}
# 49418      rxcui:358258       hgnc:9565     ~PLAIN  {other/unknown, ~NULL}
#
#       interaction_source_db_name  interaction_score  evidence_score  \
# 15852                   {ChEMBL}           0.196255             1.0
# 22106                      {NCI}           0.745769             2.0
# 29335                   {ChEMBL}           0.186442             1.0
# 34091                   {ChEMBL}           0.497179             4.0
# 34092      {MyCancerGenome, DTC}           0.497179             4.0
# 38207                   {ChEMBL}           0.191223             1.0
# 38249                   {ChEMBL}           0.177564             1.0
# 49417                   {ChEMBL}           0.350950             4.0
# 49418      {MyCancerGenome, DTC}           0.350950             4.0
#
#                    drug_name gene_name
# 15852  BORTEZOMIB D-MANNITOL     PSMD7
# 22106   PROTEASOME INHIBITOR     PSMD7
# 29335              OPROZOMIB     PSMD7
# 34091            CARFILZOMIB     PSMD7
# 34092            CARFILZOMIB     PSMD7
# 38207       IXAZOMIB CITRATE     PSMD7
# 38249               IXAZOMIB     PSMD7
# 49417             BORTEZOMIB     PSMD7
# 49418             BORTEZOMIB     PSMD7

# %% [markdown]
# ### sources logic

# %% [markdown]
# Create a mapping df: group-by "drug-gene" pair -> get a set of all sources.
#
# Then make a new sources column **mod_sources** (but in notebook, keep original so can check):
# * If "~PLAIN": use the mapping df's value for drug-gene pair (all sources)
# * Else: keep original value

# %%
experiment_sources = experiment_mergeMain.copy()

drug_gene_pair = ["drug_concept_id", "gene_concept_id"]

# %%
## need to merge sets!
## and keep multi-index, annoying but seems easier to retrieve values later
experiment_sources = experiment_sources.groupby(by=drug_gene_pair).agg(
    {"interaction_source_db_name":lambda x: set.union(*x)})

# %%
experiment_sources
# Out:
#                                                                      interaction_source_db_name
# drug_concept_id     gene_concept_id
# chembl:CHEMBL101168 hgnc:2596                                                             {DTC}
#                     hgnc:2637                                                             {DTC}
# chembl:CHEMBL10118  hgnc:30863                                                            {DTC}
# chembl:CHEMBL101510 hgnc:2625                                                             {DTC}
# chembl:CHEMBL101804 hgnc:12841                                                            {DTC}
# ...                                                                                         ...
# rxcui:9997          hgnc:644                                                              {DTC}
#                     hgnc:7876                                                        {PharmGKB}
#                     hgnc:7968                                                        {PharmGKB}
#                     hgnc:7979        {TTD, GuideToPharmacology, ChEMBL, TdgClinicalTrial, TEND}
#                     hgnc:9236                                                             {DTC}
#
# [55077 rows x 1 columns]

# %%
## trying out how to get specific value in this df using multi-index
## loc returns a series, turn to list and get first/only item

experiment_sources.loc["rxcui:1302966", "hgnc:9565"]

experiment_sources.loc["rxcui:1302966", "hgnc:9565"].to_list()[0]
# Out:
# interaction_source_db_name    {DTC, MyCancerGenome, ChEMBL}
# Name: (rxcui:1302966, hgnc:9565), dtype: object
# {'ChEMBL', 'DTC', 'MyCancerGenome'}

# %%
## add new column to experiment df
## in specific spot

mod_sources = [
    experiment_sources.loc[x.drug_concept_id, x.gene_concept_id].to_list()[0] if x.mod_type == "~PLAIN"
    else x.interaction_source_db_name
    for x in experiment_mergeMain[["drug_concept_id", "gene_concept_id", "mod_type", "interaction_source_db_name"]].itertuples()
]

experiment_mergeMain.insert(5, "mod_sources", mod_sources)

# %%
## check what rows look like with original ~PLAIN values

experiment_mergeMain[experiment_mergeMain["gene_concept_id"] == "hgnc:9565"]

experiment_mergeMain[experiment_mergeMain.duplicated(subset=["drug_concept_id", "gene_concept_id"], keep=False)][60:70]
# Out:
#         drug_concept_id gene_concept_id   mod_type       interaction_types  \
# 15852  drugbank:DB16741       hgnc:9565  inhibitor             {inhibitor}
# 22106        ncit:C2160       hgnc:9565     ~PLAIN                 {~NULL}
# 29335       ncit:C91388       hgnc:9565  inhibitor             {inhibitor}
# 34091     rxcui:1302966       hgnc:9565  inhibitor             {inhibitor}
# 34092     rxcui:1302966       hgnc:9565     ~PLAIN  {other/unknown, ~NULL}
# 38207     rxcui:1723734       hgnc:9565  inhibitor             {inhibitor}
# 38249     rxcui:1723735       hgnc:9565  inhibitor             {inhibitor}
# 49417      rxcui:358258       hgnc:9565  inhibitor             {inhibitor}
# 49418      rxcui:358258       hgnc:9565     ~PLAIN  {other/unknown, ~NULL}
#
#       interaction_source_db_name                    mod_sources  \
# 15852                   {ChEMBL}                       {ChEMBL}
# 22106                      {NCI}                          {NCI}
# 29335                   {ChEMBL}                       {ChEMBL}
# 34091                   {ChEMBL}                       {ChEMBL}
# 34092      {MyCancerGenome, DTC}  {DTC, MyCancerGenome, ChEMBL}
# 38207                   {ChEMBL}                       {ChEMBL}
# 38249                   {ChEMBL}                       {ChEMBL}
# 49417                   {ChEMBL}                       {ChEMBL}
# 49418      {MyCancerGenome, DTC}  {DTC, MyCancerGenome, ChEMBL}
#
#        interaction_score  evidence_score              drug_name gene_name
# 15852           0.196255             1.0  BORTEZOMIB D-MANNITOL     PSMD7
# 22106           0.745769             2.0   PROTEASOME INHIBITOR     PSMD7
# 29335           0.186442             1.0              OPROZOMIB     PSMD7
# 34091           0.497179             4.0            CARFILZOMIB     PSMD7
# 34092           0.497179             4.0            CARFILZOMIB     PSMD7
# 38207           0.191223             1.0       IXAZOMIB CITRATE     PSMD7
# 38249           0.177564             1.0               IXAZOMIB     PSMD7
# 49417           0.350950             4.0             BORTEZOMIB     PSMD7
# 49418           0.350950             4.0             BORTEZOMIB     PSMD7
#            drug_concept_id gene_concept_id   mod_type interaction_types  \
# 4576  chembl:CHEMBL2109391       hgnc:3613  modulator       {modulator}
# 4577  chembl:CHEMBL2109391       hgnc:3613     ~PLAIN           {~NULL}
# 4580  chembl:CHEMBL2109398       hgnc:3387  inhibitor       {inhibitor}
# 4581  chembl:CHEMBL2109398       hgnc:3387     ~PLAIN           {~NULL}
# 4583  chembl:CHEMBL2109401       hgnc:3431  inhibitor       {inhibitor}
# 4584  chembl:CHEMBL2109401       hgnc:3431     ~PLAIN           {~NULL}
# 4585  chembl:CHEMBL2109402       hgnc:3431   antibody        {antibody}
# 4586  chembl:CHEMBL2109402       hgnc:3431  inhibitor       {inhibitor}
# 4587  chembl:CHEMBL2109402       hgnc:3431     ~PLAIN           {~NULL}
# 4596  chembl:CHEMBL2109435       hgnc:4445     binder          {binder}
#
#                      interaction_source_db_name  \
# 4576                                   {ChEMBL}
# 4577                                      {NCI}
# 4580                                   {ChEMBL}
# 4581                                      {TTD}
# 4583                                   {ChEMBL}
# 4584                                      {TTD}
# 4585                           {MyCancerGenome}
# 4586  {ClearityFoundationClinicalTrial, ChEMBL}
# 4587                                      {TTD}
# 4596                                   {ChEMBL}
#
#                                                          mod_sources  \
# 4576                                                        {ChEMBL}
# 4577                                                   {NCI, ChEMBL}
# 4580                                                        {ChEMBL}
# 4581                                                   {TTD, ChEMBL}
# 4583                                                        {ChEMBL}
# 4584                                                   {TTD, ChEMBL}
# 4585                                                {MyCancerGenome}
# 4586                       {ClearityFoundationClinicalTrial, ChEMBL}
# 4587  {ClearityFoundationClinicalTrial, TTD, MyCancerGenome, ChEMBL}
# 4596                                                        {ChEMBL}
#
#       interaction_score  evidence_score drug_name gene_name
# 4576          15.661140             3.0   MDX-447    FCGR1A
# 4577          15.661140             3.0   MDX-447    FCGR1A
# 4580          10.440760             2.0    KB-004     EPHA3
# 4581          10.440760             2.0    KB-004     EPHA3
# 4583           2.007838             2.0    AV-203     ERBB3
# 4584           2.007838             2.0    AV-203     ERBB3
# 4585           4.015677             4.0    MM-121     ERBB3
# 4586           4.015677             4.0    MM-121     ERBB3
# 4587           4.015677             4.0    MM-121     ERBB3
# 4596          26.101899             2.0     HUA33     GPA33

# %% [markdown]
# ### scores logic

# %% [markdown]
# In notebook, creating new df rather than working on old to make easier to adjust
#
# Only care about logic for removing scores (setting NA)
#
# Group by "drug-gene" pair:
# * If there's > 1 row (mod_type):
#   * If row mod_type isn't "~PLAIN": remove scores

# %%
experiment_scores = experiment_mergeMain.copy()

drug_gene_pair = ["drug_concept_id", "gene_concept_id"]

# %%
## iterate through a group-by

grp = experiment_scores.groupby(by=drug_gene_pair)

for name, group in grp:
    if group.shape[0] > 1:
        for idx,row in group.iterrows():
            if row.mod_type != "~PLAIN":
                experiment_scores.at[idx, "interaction_score"] = pd.NA
                experiment_scores.at[idx, "evidence_score"] = pd.NA

# %%
## check what rows look like
## some scores are now NA! 58,830 VS 55,030 

experiment_scores.info()

experiment_scores[experiment_scores["interaction_score"].isna()].shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58830 entries, 0 to 58829
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   drug_concept_id             58830 non-null  object
#  1   gene_concept_id             58830 non-null  object
#  2   mod_type                    58830 non-null  object
#  3   interaction_types           58830 non-null  object
#  4   interaction_source_db_name  58830 non-null  object
#  5   mod_sources                 58830 non-null  object
#  6   interaction_score           55030 non-null  float64
#  7   evidence_score              55030 non-null  float64
#  8   drug_name                   58830 non-null  object
#  9   gene_name                   58830 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 4.5+ MB
# 3800

# %%
## check what rows look like

experiment_scores[experiment_scores["gene_concept_id"] == "hgnc:9565"]

experiment_scores[experiment_scores.duplicated(subset=["drug_concept_id", "gene_concept_id"], keep=False)][60:70]
# Out:
#         drug_concept_id gene_concept_id   mod_type       interaction_types  \
# 15852  drugbank:DB16741       hgnc:9565  inhibitor             {inhibitor}
# 22106        ncit:C2160       hgnc:9565     ~PLAIN                 {~NULL}
# 29335       ncit:C91388       hgnc:9565  inhibitor             {inhibitor}
# 34091     rxcui:1302966       hgnc:9565  inhibitor             {inhibitor}
# 34092     rxcui:1302966       hgnc:9565     ~PLAIN  {other/unknown, ~NULL}
# 38207     rxcui:1723734       hgnc:9565  inhibitor             {inhibitor}
# 38249     rxcui:1723735       hgnc:9565  inhibitor             {inhibitor}
# 49417      rxcui:358258       hgnc:9565  inhibitor             {inhibitor}
# 49418      rxcui:358258       hgnc:9565     ~PLAIN  {other/unknown, ~NULL}
#
#       interaction_source_db_name                    mod_sources  \
# 15852                   {ChEMBL}                       {ChEMBL}
# 22106                      {NCI}                          {NCI}
# 29335                   {ChEMBL}                       {ChEMBL}
# 34091                   {ChEMBL}                       {ChEMBL}
# 34092      {MyCancerGenome, DTC}  {DTC, MyCancerGenome, ChEMBL}
# 38207                   {ChEMBL}                       {ChEMBL}
# 38249                   {ChEMBL}                       {ChEMBL}
# 49417                   {ChEMBL}                       {ChEMBL}
# 49418      {MyCancerGenome, DTC}  {DTC, MyCancerGenome, ChEMBL}
#
#        interaction_score  evidence_score              drug_name gene_name
# 15852           0.196255             1.0  BORTEZOMIB D-MANNITOL     PSMD7
# 22106           0.745769             2.0   PROTEASOME INHIBITOR     PSMD7
# 29335           0.186442             1.0              OPROZOMIB     PSMD7
# 34091                NaN             NaN            CARFILZOMIB     PSMD7
# 34092           0.497179             4.0            CARFILZOMIB     PSMD7
# 38207           0.191223             1.0       IXAZOMIB CITRATE     PSMD7
# 38249           0.177564             1.0               IXAZOMIB     PSMD7
# 49417                NaN             NaN             BORTEZOMIB     PSMD7
# 49418           0.350950             4.0             BORTEZOMIB     PSMD7
#            drug_concept_id gene_concept_id   mod_type interaction_types  \
# 4576  chembl:CHEMBL2109391       hgnc:3613  modulator       {modulator}
# 4577  chembl:CHEMBL2109391       hgnc:3613     ~PLAIN           {~NULL}
# 4580  chembl:CHEMBL2109398       hgnc:3387  inhibitor       {inhibitor}
# 4581  chembl:CHEMBL2109398       hgnc:3387     ~PLAIN           {~NULL}
# 4583  chembl:CHEMBL2109401       hgnc:3431  inhibitor       {inhibitor}
# 4584  chembl:CHEMBL2109401       hgnc:3431     ~PLAIN           {~NULL}
# 4585  chembl:CHEMBL2109402       hgnc:3431   antibody        {antibody}
# 4586  chembl:CHEMBL2109402       hgnc:3431  inhibitor       {inhibitor}
# 4587  chembl:CHEMBL2109402       hgnc:3431     ~PLAIN           {~NULL}
# 4596  chembl:CHEMBL2109435       hgnc:4445     binder          {binder}
#
#                      interaction_source_db_name  \
# 4576                                   {ChEMBL}
# 4577                                      {NCI}
# 4580                                   {ChEMBL}
# 4581                                      {TTD}
# 4583                                   {ChEMBL}
# 4584                                      {TTD}
# 4585                           {MyCancerGenome}
# 4586  {ClearityFoundationClinicalTrial, ChEMBL}
# 4587                                      {TTD}
# 4596                                   {ChEMBL}
#
#                                                          mod_sources  \
# 4576                                                        {ChEMBL}
# 4577                                                   {NCI, ChEMBL}
# 4580                                                        {ChEMBL}
# 4581                                                   {TTD, ChEMBL}
# 4583                                                        {ChEMBL}
# 4584                                                   {TTD, ChEMBL}
# 4585                                                {MyCancerGenome}
# 4586                       {ClearityFoundationClinicalTrial, ChEMBL}
# 4587  {ClearityFoundationClinicalTrial, TTD, MyCancerGenome, ChEMBL}
# 4596                                                        {ChEMBL}
#
#       interaction_score  evidence_score drug_name gene_name
# 4576                NaN             NaN   MDX-447    FCGR1A
# 4577          15.661140             3.0   MDX-447    FCGR1A
# 4580                NaN             NaN    KB-004     EPHA3
# 4581          10.440760             2.0    KB-004     EPHA3
# 4583                NaN             NaN    AV-203     ERBB3
# 4584           2.007838             2.0    AV-203     ERBB3
# 4585                NaN             NaN    MM-121     ERBB3
# 4586                NaN             NaN    MM-121     ERBB3
# 4587           4.015677             4.0    MM-121     ERBB3
# 4596                NaN             NaN     HUA33     GPA33
